# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np
# Open the HDF5 file
hdf5_file = h5py.File('profiles/profile_0.h5', 'r')

# Read the data
time_2 = hdf5_file['time'][:]
B_OBS1_2 = hdf5_file['B_OBS1'][:]
B_OBS2_2 = hdf5_file['B_OBS2'][:]
B_OBS3_2 = hdf5_file['B_OBS3'][:]
time_str = np.char.decode(time_2)
time_only = np.array([s.split(' ')[1] for s in time_str])
time_only
# Plot the data
# Out:
# array(['00:05:30.977225', '00:05:31.102225', '00:05:31.227225', ...,
#        '00:19:30.592839', '00:19:30.717839', '00:19:30.842839'],
#       dtype='<U15')

# %%
plt.plot(time_only, B_OBS2_2, label='B_OBS1')
plt.show()
